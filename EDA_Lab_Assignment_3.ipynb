# %% [markdown]
# <a href="https://colab.research.google.com/github/panchaldhruv27223/DA_EDA/blob/main/EDA_Lab_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eb3f681e-e3ac-4740-9c05-514e9f53e220" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb3f681e-e3ac-4740-9c05-514e9f53e220">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Read the dataset

# %%
df =  pd.read_csv("/content/melb_data.csv")

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# ## Columns that having Missing values are :
#     Car
#     BuildingArea
#     YearBuilt
#     CounlcilArea

# %% [markdown]
# ## Applying some preprocessing steps

# %%
# Unique values in categorical columns
print(df['Car'].unique())
print(df['Rooms'].unique())
print(df['Price'].unique())
# Out:
# [ 1.  0.  2.  6.  5.  4.  3.  8.  7.  9. 10. nan]
# [ 2  3  4  1  6  5  8  7 10]
# [1480000. 1035000. 1465000. ... 1288000. 1263500. 1323000.]

# %% [markdown]
# ### Data Cleaning

# %%
df_cleaned = df.drop_duplicates(keep="first")
df_cleaned
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df_cleaned["Date"] = pd.to_datetime(df_cleaned["Date"], dayfirst = True)
df_cleaned
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG       Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df_cleaned["Year"] = df_cleaned["Date"].dt.year
df_cleaned["Month"] = df_cleaned["Date"].dt.month
df_cleaned["day"] = df_cleaned["Date"].dt.day
df_cleaned
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG       Date  Distance  Postcode  ...  BuildingArea  YearBuilt  \
# ...

# %%
df_cleaned.dtypes
# Out:
# Suburb                   object
# Address                  object
# Rooms                     int64
# Type                     object
# Price                   float64
# Method                   object
# SellerG                  object
# Date             datetime64[ns]
# Distance                float64
# Postcode                float64
# Bedroom2                float64
# Bathroom                float64
# Car                     float64
# Landsize                float64
# BuildingArea            float64
# YearBuilt               float64
# CouncilArea              object
# Lattitude               float64
# Longtitude              float64
# Regionname               object
# Propertycount           float64
# Year                      int32
# Month                     int32
# day                       int32
# dtype: object

# %%
pd.set_option("display.max_columns",None)

# %%
df_cleaned.head(5)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0 2016-12-03       2.5    3067.0       2.0       1.0  1.0     202.0
# 1 2016-02-04       2.5    3067.0       2.0       1.0  0.0     156.0
# 2 2017-03-04       2.5    3067.0       3.0       2.0  0.0     134.0
# 3 2017-03-04       2.5    3067.0       3.0       2.0  1.0      94.0
# 4 2016-06-04       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN       Yarra   -37.7996    144.9984
# ...

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
(df.isnull().sum() / (len(df)) ) * 100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price             0.000000
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          0.000000
# Bathroom          0.000000
# Car               0.456554
# Landsize          0.000000
# BuildingArea     47.496318
# YearBuilt        39.580265
# CouncilArea      10.081001
# Lattitude         0.000000
# Longtitude        0.000000
# Regionname        0.000000
# Propertycount     0.000000
# dtype: float64

# %%
import missingno

# %%
missingno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# #### observation :
#
# ## "Car", "YearBuilt", "CouncilArea" containing the missing values.

# %%
missingno.matrix(df)
# Out:
# <Axes: >

# %%
missingno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# ### Create the copy of the dataset

# %%
df_1 = df.copy()
df_2 = df.copy()

# %% [markdown]
# ### TO handle the missing values we have different type of techniques
# Drop the rows
#
# Drop the columns
#
# fill by constant or fill by mean or fill by mode

# %% [markdown]
# ### DROP ROWS

# %%
df.shape
# Out:
# (13580, 21)

# %%
df_drop_row = df_1.dropna(axis=0)
df_drop_row.head(2)
df_drop_row.shape
# Out:
# (6196, 21)

# %%
13580 - 6196
# Out:
# 7384

# %% [markdown]
# ### If we Drop the row which containing missing values then we loss most of the data values so droping rows is not a good idea. loss of : 7384 rows

# %%
df_drop_col = df_2.dropna(axis=1)
df_drop_col.shape
# Out:
# (13580, 17)

# %%
21 - 17
# Out:
# 4

# %% [markdown]
# ## If we drop the columns then we loss the 4 features entirely.

# %%
len(df_2[df_2["BuildingArea"] == 0 ]["BuildingArea"])
# Out:
# 17

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
len(df_2) - 6450
# Out:
# 7130

# %% [markdown]
# ## In out dataset we can see that feature BuildingArea has 47% missing values and it contain a object type data. so if we want to fill the missing values of that columns then we have to use mod. but if we see the percentages of the missng value, i think it is better to drop that type of features.

# %% [markdown]
# ## Droping the columns "BuildingArea"

# %%
df.drop(["BuildingArea"], axis=1, inplace=True)
df.head(2)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford     85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
#
#    YearBuilt CouncilArea  Lattitude  Longtitude             Regionname  \
# 0        NaN       Yarra   -37.7996    144.9984  Northern Metropolitan
# 1     1900.0       Yarra   -37.8079    144.9934  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0

# %%
df["Car"].unique()
# Out:
# array([ 1.,  0.,  2.,  6.,  5.,  4.,  3.,  8.,  7.,  9., 10., nan])

# %%
df["Car"].isnull().sum()
# Out:
# 62

# %%
len(df)
# Out:
# 13580

# %%
df["YearBuilt"].unique()
# Out:
# array([  nan, 1900., 2014., 1910., 1890., 2005., 2009., 1880., 1985.,
#        2010., 1970., 2013., 2012., 1920., 1950., 1998., 1930., 2016.,
#        1965., 1980., 2011., 2015., 1975., 1993., 1960., 2003., 1995.,
#        1996., 2000., 1925., 2004., 2008., 1962., 1955., 1988., 1953.,
#        1997., 1990., 2007., 1967., 1964., 1889., 1888., 2006., 1934.,
#        1935., 1966., 1969., 1940., 1938., 1887., 1904., 1972., 1978.,
#        1939., 1945., 1947., 1958., 2017., 1999., 1992., 1961., 1928.,
#        1977., 1976., 2001., 1948., 1927., 1981., 1943., 1974., 1968.,
#        1957., 1987., 1986., 1926., 2002., 1994., 1949., 1905., 1912.,
#        1924., 1952., 1991., 1942., 1973., 1915., 2018., 1916., 1982.,
#        1971., 1963., 1897., 1989., 1919., 1923., 1983., 1903., 1830.,
#        1895., 1937., 1908., 1913., 1917., 1885., 1902., 1854., 1850.,
#        1898., 1941., 1951., 1946., 1956., 1984., 1901., 1959., 1979.,
# ...

# %%
df["CouncilArea"].unique()
# Out:
# array(['Yarra', 'Moonee Valley', 'Port Phillip', 'Darebin', 'Hobsons Bay',
#        'Stonnington', 'Boroondara', 'Monash', 'Glen Eira', 'Whitehorse',
#        'Maribyrnong', 'Bayside', 'Moreland', 'Manningham', 'Banyule',
#        'Melbourne', 'Kingston', 'Brimbank', 'Hume', nan, 'Knox',
#        'Maroondah', 'Casey', 'Melton', 'Greater Dandenong', 'Nillumbik',
#        'Whittlesea', 'Frankston', 'Macedon Ranges', 'Yarra Ranges',
#        'Wyndham', 'Cardinia', 'Unavailable', 'Moorabool'], dtype=object)

# %%
df["CouncilArea"].isnull().sum()
# Out:
# 1369

# %%
df["CouncilArea"].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Here we can see that CouncilArea and YearBuilt is Object type so to fill that missing values by filling the mode value of the columns.

# %%
df["CouncilArea"].mode()
# Out:
# 0    Moreland
# Name: CouncilArea, dtype: object

# %%
df["CouncilArea"].value_counts()
# Out:
# CouncilArea
# Moreland             1163
# Boroondara           1160
# Moonee Valley         997
# Darebin               934
# Glen Eira             848
# Stonnington           719
# Maribyrnong           692
# Yarra                 647
# Port Phillip          628
# Banyule               594
# Bayside               489
# Melbourne             470
# Hobsons Bay           434
# Brimbank              424
# Monash                333
# Manningham            311
# Whitehorse            304
# Kingston              207
# Whittlesea            167
# Hume                  164
# Wyndham                86
# Knox                   80
# Maroondah              80
# Melton                 66
# Frankston              53
# Greater Dandenong      52
# Casey                  38
# Nillumbik              36
# Yarra Ranges           18
# Cardinia                8
# Macedon Ranges          7
# Unavailable             1
# Moorabool               1
# Name: count, dtype: int64

# %%
df["YearBuilt"].unique()
# Out:
# array([  nan, 1900., 2014., 1910., 1890., 2005., 2009., 1880., 1985.,
#        2010., 1970., 2013., 2012., 1920., 1950., 1998., 1930., 2016.,
#        1965., 1980., 2011., 2015., 1975., 1993., 1960., 2003., 1995.,
#        1996., 2000., 1925., 2004., 2008., 1962., 1955., 1988., 1953.,
#        1997., 1990., 2007., 1967., 1964., 1889., 1888., 2006., 1934.,
#        1935., 1966., 1969., 1940., 1938., 1887., 1904., 1972., 1978.,
#        1939., 1945., 1947., 1958., 2017., 1999., 1992., 1961., 1928.,
#        1977., 1976., 2001., 1948., 1927., 1981., 1943., 1974., 1968.,
#        1957., 1987., 1986., 1926., 2002., 1994., 1949., 1905., 1912.,
#        1924., 1952., 1991., 1942., 1973., 1915., 2018., 1916., 1982.,
#        1971., 1963., 1897., 1989., 1919., 1923., 1983., 1903., 1830.,
#        1895., 1937., 1908., 1913., 1917., 1885., 1902., 1854., 1850.,
#        1898., 1941., 1951., 1946., 1956., 1984., 1901., 1959., 1979.,
# ...

# %%
df["YearBuilt"].value_counts()
# Out:
# YearBuilt
# 1970.0    866
# 1960.0    725
# 1950.0    580
# 1900.0    341
# 1980.0    338
#          ...
# 1897.0      1
# 1933.0      1
# 1830.0      1
# 1901.0      1
# 1857.0      1
# Name: count, Length: 144, dtype: int64

# %%
df[["CouncilArea"]] = df[["CouncilArea"]].fillna("Moreland")

# %%
df[["YearBuilt"]] = df[["YearBuilt"]].fillna(1970.0)

# %%
df.isnull().sum()
# Out:
# Suburb            0
# Address           0
# Rooms             0
# Type              0
# Price             0
# Method            0
# SellerG           0
# Date              0
# Distance          0
# Postcode          0
# Bedroom2          0
# Bathroom          0
# Car              62
# Landsize          0
# YearBuilt         0
# CouncilArea       0
# Lattitude         0
# Longtitude        0
# Regionname        0
# Propertycount     0
# dtype: int64

# %% [markdown]
# ### The one columnes remaining is Car and to handle the missing values of that columns the best we can do is fill by the average number of that perticular column.

# %%
df["Car"].mean()
# Out:
# 1.6100754549489569

# %%
df["Car"].value_counts()
# Out:
# Car
# 2.0     5591
# 1.0     5509
# 0.0     1026
# 3.0      748
# 4.0      506
# 5.0       63
# 6.0       54
# 8.0        9
# 7.0        8
# 10.0       3
# 9.0        1
# Name: count, dtype: int64

# %% [markdown]
# #### There is only 32 row which not contain the value of the "car" and from obsevation we can say that the most of the values are either 1 or 2 and also the average value is 1.610075. so the one solution is just drop that 32 rows or other one is filling it by the value 2.

# %%
df["Car"] = df["Car"].fillna(2)

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.to_csv("clean_Data.csv",index=False)
